# %%
import numpy as np
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
X, y = iris.data, iris.target

# %%
from keras.utils import to_categorical

# %%
y = to_categorical(y)

# %%
y.shape
# Out:
# (150, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

scaled_X_train = scaler.fit_transform(X_train)
scalted_X_test = scaler.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(8, input_dim=4, activation='relu'))
model.add(Dense(8, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics =['accuracy'])

# %%
model.fit(scaled_X_train, y_train, epochs=150, verbose=2)
# Out:
# Epoch 1/150
# 2024-04-22 07:41:28.188791: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 4/4 - 0s - loss: 1.1032 - accuracy: 0.3200 - 392ms/epoch - 98ms/step
# Epoch 2/150
# 4/4 - 0s - loss: 1.0975 - accuracy: 0.3200 - 2ms/epoch - 543us/step
# Epoch 3/150
# 4/4 - 0s - loss: 1.0926 - accuracy: 0.3100 - 2ms/epoch - 423us/step
# Epoch 4/150
# 4/4 - 0s - loss: 1.0879 - accuracy: 0.3500 - 2ms/epoch - 613us/step
# Epoch 5/150
# 4/4 - 0s - loss: 1.0831 - accuracy: 0.4400 - 2ms/epoch - 437us/step
# Epoch 6/150
# 4/4 - 0s - loss: 1.0780 - accuracy: 0.5900 - 4ms/epoch - 878us/step
# Epoch 7/150
# 4/4 - 0s - loss: 1.0729 - accuracy: 0.6300 - 3ms/epoch - 628us/step
# Epoch 8/150
# 4/4 - 0s - loss: 1.0675 - accuracy: 0.6500 - 2ms/epoch - 623us/step
# Epoch 9/150
# 4/4 - 0s - loss: 1.0616 - accuracy: 0.6500 - 3ms/epoch - 670us/step
# Epoch 10/150
# 4/4 - 0s - loss: 1.0555 - accuracy: 0.6500 - 2ms/epoch - 601us/step
# Epoch 11/150
# 4/4 - 0s - loss: 1.0495 - accuracy: 0.6500 - 4ms/epoch - 891us/step
# Epoch 12/150
# 4/4 - 0s - loss: 1.0435 - accuracy: 0.6500 - 2ms/epoch - 486us/step
# Epoch 13/150
# 4/4 - 0s - loss: 1.0373 - accuracy: 0.6500 - 5ms/epoch - 1ms/step
# Epoch 14/150
# 4/4 - 0s - loss: 1.0311 - accuracy: 0.6500 - 3ms/epoch - 731us/step
# Epoch 15/150
# 4/4 - 0s - loss: 1.0249 - accuracy: 0.6500 - 3ms/epoch - 700us/step
# Epoch 16/150
# 4/4 - 0s - loss: 1.0183 - accuracy: 0.6500 - 5ms/epoch - 1ms/step
# Epoch 17/150
# 4/4 - 0s - loss: 1.0114 - accuracy: 0.6500 - 5ms/epoch - 1ms/step
# Epoch 18/150
# 4/4 - 0s - loss: 1.0045 - accuracy: 0.6500 - 4ms/epoch - 988us/step
# Epoch 19/150
# 4/4 - 0s - loss: 0.9972 - accuracy: 0.6500 - 3ms/epoch - 743us/step
# Epoch 20/150
# 4/4 - 0s - loss: 0.9898 - accuracy: 0.6500 - 2ms/epoch - 475us/step
# Epoch 21/150
# 4/4 - 0s - loss: 0.9821 - accuracy: 0.6500 - 3ms/epoch - 804us/step
# Epoch 22/150
# 4/4 - 0s - loss: 0.9742 - accuracy: 0.6500 - 4ms/epoch - 932us/step
# Epoch 23/150
# 4/4 - 0s - loss: 0.9664 - accuracy: 0.6500 - 3ms/epoch - 666us/step
# Epoch 24/150
# 4/4 - 0s - loss: 0.9589 - accuracy: 0.6500 - 3ms/epoch - 714us/step
# Epoch 25/150
# 4/4 - 0s - loss: 0.9516 - accuracy: 0.6500 - 4ms/epoch - 902us/step
# Epoch 26/150
# 4/4 - 0s - loss: 0.9445 - accuracy: 0.6500 - 3ms/epoch - 793us/step
# Epoch 27/150
# 4/4 - 0s - loss: 0.9374 - accuracy: 0.6500 - 3ms/epoch - 853us/step
# Epoch 28/150
# 4/4 - 0s - loss: 0.9302 - accuracy: 0.6500 - 3ms/epoch - 690us/step
# Epoch 29/150
# 4/4 - 0s - loss: 0.9233 - accuracy: 0.6500 - 3ms/epoch - 685us/step
# Epoch 30/150
# 4/4 - 0s - loss: 0.9166 - accuracy: 0.6500 - 3ms/epoch - 870us/step
# Epoch 31/150
# 4/4 - 0s - loss: 0.9101 - accuracy: 0.6500 - 2ms/epoch - 612us/step
# Epoch 32/150
# 4/4 - 0s - loss: 0.9034 - accuracy: 0.6500 - 2ms/epoch - 511us/step
# Epoch 33/150
# 4/4 - 0s - loss: 0.8966 - accuracy: 0.6500 - 4ms/epoch - 1ms/step
# Epoch 34/150
# 4/4 - 0s - loss: 0.8895 - accuracy: 0.6500 - 3ms/epoch - 661us/step
# Epoch 35/150
# 4/4 - 0s - loss: 0.8823 - accuracy: 0.6500 - 18ms/epoch - 5ms/step
# Epoch 36/150
# 4/4 - 0s - loss: 0.8753 - accuracy: 0.6500 - 18ms/epoch - 4ms/step
# Epoch 37/150
# 4/4 - 0s - loss: 0.8682 - accuracy: 0.6500 - 10ms/epoch - 3ms/step
# Epoch 38/150
# 4/4 - 0s - loss: 0.8612 - accuracy: 0.6500 - 18ms/epoch - 4ms/step
# Epoch 39/150
# 4/4 - 0s - loss: 0.8537 - accuracy: 0.6500 - 14ms/epoch - 3ms/step
# Epoch 40/150
# 4/4 - 0s - loss: 0.8464 - accuracy: 0.6500 - 20ms/epoch - 5ms/step
# Epoch 41/150
# 4/4 - 0s - loss: 0.8393 - accuracy: 0.6500 - 17ms/epoch - 4ms/step
# Epoch 42/150
# 4/4 - 0s - loss: 0.8323 - accuracy: 0.6500 - 13ms/epoch - 3ms/step
# Epoch 43/150
# 4/4 - 0s - loss: 0.8249 - accuracy: 0.6500 - 19ms/epoch - 5ms/step
# Epoch 44/150
# 4/4 - 0s - loss: 0.8173 - accuracy: 0.6400 - 14ms/epoch - 3ms/step
# Epoch 45/150
# 4/4 - 0s - loss: 0.8101 - accuracy: 0.6600 - 6ms/epoch - 1ms/step
# Epoch 46/150
# 4/4 - 0s - loss: 0.8026 - accuracy: 0.6800 - 4ms/epoch - 907us/step
# Epoch 47/150
# 4/4 - 0s - loss: 0.7948 - accuracy: 0.6500 - 5ms/epoch - 1ms/step
# Epoch 48/150
# 4/4 - 0s - loss: 0.7870 - accuracy: 0.6100 - 10ms/epoch - 3ms/step
# Epoch 49/150
# 4/4 - 0s - loss: 0.7792 - accuracy: 0.6200 - 13ms/epoch - 3ms/step
# Epoch 50/150
# 4/4 - 0s - loss: 0.7711 - accuracy: 0.6000 - 17ms/epoch - 4ms/step
# Epoch 51/150
# 4/4 - 0s - loss: 0.7641 - accuracy: 0.6200 - 13ms/epoch - 3ms/step
# Epoch 52/150
# 4/4 - 0s - loss: 0.7551 - accuracy: 0.6400 - 17ms/epoch - 4ms/step
# Epoch 53/150
# 4/4 - 0s - loss: 0.7472 - accuracy: 0.6400 - 5ms/epoch - 1ms/step
# Epoch 54/150
# 4/4 - 0s - loss: 0.7395 - accuracy: 0.6400 - 3ms/epoch - 659us/step
# Epoch 55/150
# 4/4 - 0s - loss: 0.7325 - accuracy: 0.6400 - 2ms/epoch - 607us/step
# Epoch 56/150
# 4/4 - 0s - loss: 0.7253 - accuracy: 0.6400 - 13ms/epoch - 3ms/step
# Epoch 57/150
# 4/4 - 0s - loss: 0.7187 - accuracy: 0.6400 - 11ms/epoch - 3ms/step
# Epoch 58/150
# 4/4 - 0s - loss: 0.7117 - accuracy: 0.6400 - 7ms/epoch - 2ms/step
# Epoch 59/150
# 4/4 - 0s - loss: 0.7050 - accuracy: 0.6400 - 5ms/epoch - 1ms/step
# Epoch 60/150
# 4/4 - 0s - loss: 0.6984 - accuracy: 0.6400 - 4ms/epoch - 877us/step
# Epoch 61/150
# 4/4 - 0s - loss: 0.6916 - accuracy: 0.6400 - 4ms/epoch - 1ms/step
# Epoch 62/150
# 4/4 - 0s - loss: 0.6845 - accuracy: 0.6400 - 4ms/epoch - 1ms/step
# Epoch 63/150
# 4/4 - 0s - loss: 0.6786 - accuracy: 0.6500 - 4ms/epoch - 1ms/step
# Epoch 64/150
# 4/4 - 0s - loss: 0.6722 - accuracy: 0.6500 - 4ms/epoch - 1ms/step
# Epoch 65/150
# 4/4 - 0s - loss: 0.6660 - accuracy: 0.6500 - 11ms/epoch - 3ms/step
# Epoch 66/150
# 4/4 - 0s - loss: 0.6600 - accuracy: 0.6500 - 7ms/epoch - 2ms/step
# Epoch 67/150
# 4/4 - 0s - loss: 0.6542 - accuracy: 0.6500 - 6ms/epoch - 2ms/step
# Epoch 68/150
# 4/4 - 0s - loss: 0.6480 - accuracy: 0.6500 - 4ms/epoch - 949us/step
# Epoch 69/150
# 4/4 - 0s - loss: 0.6423 - accuracy: 0.6500 - 2ms/epoch - 485us/step
# Epoch 70/150
# 4/4 - 0s - loss: 0.6362 - accuracy: 0.6500 - 2ms/epoch - 530us/step
# Epoch 71/150
# 4/4 - 0s - loss: 0.6304 - accuracy: 0.6500 - 3ms/epoch - 660us/step
# Epoch 72/150
# 4/4 - 0s - loss: 0.6249 - accuracy: 0.6500 - 4ms/epoch - 1ms/step
# Epoch 73/150
# 4/4 - 0s - loss: 0.6191 - accuracy: 0.6500 - 2ms/epoch - 479us/step
# Epoch 74/150
# 4/4 - 0s - loss: 0.6139 - accuracy: 0.6500 - 2ms/epoch - 453us/step
# Epoch 75/150
# 4/4 - 0s - loss: 0.6086 - accuracy: 0.6500 - 4ms/epoch - 973us/step
# Epoch 76/150
# 4/4 - 0s - loss: 0.6035 - accuracy: 0.6500 - 2ms/epoch - 477us/step
# Epoch 77/150
# 4/4 - 0s - loss: 0.5983 - accuracy: 0.6500 - 3ms/epoch - 642us/step
# Epoch 78/150
# 4/4 - 0s - loss: 0.5936 - accuracy: 0.6500 - 3ms/epoch - 636us/step
# Epoch 79/150
# 4/4 - 0s - loss: 0.5891 - accuracy: 0.6500 - 3ms/epoch - 671us/step
# Epoch 80/150
# 4/4 - 0s - loss: 0.5842 - accuracy: 0.6500 - 2ms/epoch - 422us/step
# Epoch 81/150
# 4/4 - 0s - loss: 0.5796 - accuracy: 0.6500 - 2ms/epoch - 377us/step
# Epoch 82/150
# 4/4 - 0s - loss: 0.5760 - accuracy: 0.6500 - 2ms/epoch - 512us/step
# Epoch 83/150
# 4/4 - 0s - loss: 0.5718 - accuracy: 0.6500 - 2ms/epoch - 565us/step
# Epoch 84/150
# 4/4 - 0s - loss: 0.5677 - accuracy: 0.6500 - 2ms/epoch - 410us/step
# Epoch 85/150
# 4/4 - 0s - loss: 0.5633 - accuracy: 0.6500 - 2ms/epoch - 378us/step
# Epoch 86/150
# 4/4 - 0s - loss: 0.5589 - accuracy: 0.6500 - 2ms/epoch - 452us/step
# Epoch 87/150
# 4/4 - 0s - loss: 0.5550 - accuracy: 0.6500 - 2ms/epoch - 431us/step
# Epoch 88/150
# 4/4 - 0s - loss: 0.5507 - accuracy: 0.6500 - 2ms/epoch - 393us/step
# Epoch 89/150
# 4/4 - 0s - loss: 0.5467 - accuracy: 0.6600 - 2ms/epoch - 617us/step
# Epoch 90/150
# 4/4 - 0s - loss: 0.5428 - accuracy: 0.6600 - 2ms/epoch - 497us/step
# Epoch 91/150
# 4/4 - 0s - loss: 0.5392 - accuracy: 0.6600 - 2ms/epoch - 423us/step
# Epoch 92/150
# 4/4 - 0s - loss: 0.5355 - accuracy: 0.6600 - 2ms/epoch - 403us/step
# Epoch 93/150
# 4/4 - 0s - loss: 0.5318 - accuracy: 0.6600 - 1ms/epoch - 364us/step
# Epoch 94/150
# 4/4 - 0s - loss: 0.5281 - accuracy: 0.6700 - 1ms/epoch - 374us/step
# Epoch 95/150
# 4/4 - 0s - loss: 0.5247 - accuracy: 0.6700 - 2ms/epoch - 556us/step
# Epoch 96/150
# 4/4 - 0s - loss: 0.5215 - accuracy: 0.6700 - 2ms/epoch - 577us/step
# Epoch 97/150
# 4/4 - 0s - loss: 0.5182 - accuracy: 0.6700 - 2ms/epoch - 419us/step
# Epoch 98/150
# 4/4 - 0s - loss: 0.5148 - accuracy: 0.6700 - 2ms/epoch - 424us/step
# Epoch 99/150
# 4/4 - 0s - loss: 0.5114 - accuracy: 0.6700 - 2ms/epoch - 519us/step
# Epoch 100/150
# 4/4 - 0s - loss: 0.5082 - accuracy: 0.6700 - 2ms/epoch - 416us/step
# Epoch 101/150
# 4/4 - 0s - loss: 0.5049 - accuracy: 0.6700 - 2ms/epoch - 381us/step
# Epoch 102/150
# 4/4 - 0s - loss: 0.5020 - accuracy: 0.6800 - 2ms/epoch - 518us/step
# Epoch 103/150
# 4/4 - 0s - loss: 0.4990 - accuracy: 0.6800 - 3ms/epoch - 669us/step
# Epoch 104/150
# 4/4 - 0s - loss: 0.4960 - accuracy: 0.6800 - 2ms/epoch - 483us/step
# Epoch 105/150
# 4/4 - 0s - loss: 0.4933 - accuracy: 0.6800 - 4ms/epoch - 981us/step
# Epoch 106/150
# 4/4 - 0s - loss: 0.4903 - accuracy: 0.6800 - 3ms/epoch - 650us/step
# Epoch 107/150
# 4/4 - 0s - loss: 0.4874 - accuracy: 0.6800 - 4ms/epoch - 1ms/step
# Epoch 108/150
# 4/4 - 0s - loss: 0.4845 - accuracy: 0.7000 - 6ms/epoch - 1ms/step
# Epoch 109/150
# 4/4 - 0s - loss: 0.4813 - accuracy: 0.7400 - 4ms/epoch - 890us/step
# Epoch 110/150
# 4/4 - 0s - loss: 0.4784 - accuracy: 0.7600 - 6ms/epoch - 2ms/step
# Epoch 111/150
# 4/4 - 0s - loss: 0.4755 - accuracy: 0.7800 - 2ms/epoch - 561us/step
# Epoch 112/150
# 4/4 - 0s - loss: 0.4725 - accuracy: 0.7800 - 3ms/epoch - 642us/step
# Epoch 113/150
# 4/4 - 0s - loss: 0.4691 - accuracy: 0.7800 - 2ms/epoch - 497us/step
# Epoch 114/150
# 4/4 - 0s - loss: 0.4677 - accuracy: 0.7800 - 4ms/epoch - 949us/step
# Epoch 115/150
# 4/4 - 0s - loss: 0.4647 - accuracy: 0.7500 - 3ms/epoch - 875us/step
# Epoch 116/150
# 4/4 - 0s - loss: 0.4616 - accuracy: 0.7800 - 3ms/epoch - 701us/step
# Epoch 117/150
# 4/4 - 0s - loss: 0.4590 - accuracy: 0.7900 - 2ms/epoch - 495us/step
# Epoch 118/150
# 4/4 - 0s - loss: 0.4562 - accuracy: 0.8100 - 2ms/epoch - 598us/step
# Epoch 119/150
# 4/4 - 0s - loss: 0.4541 - accuracy: 0.8500 - 2ms/epoch - 546us/step
# Epoch 120/150
# 4/4 - 0s - loss: 0.4513 - accuracy: 0.8700 - 2ms/epoch - 402us/step
# Epoch 121/150
# 4/4 - 0s - loss: 0.4484 - accuracy: 0.8700 - 2ms/epoch - 411us/step
# Epoch 122/150
# 4/4 - 0s - loss: 0.4458 - accuracy: 0.8700 - 3ms/epoch - 778us/step
# Epoch 123/150
# 4/4 - 0s - loss: 0.4433 - accuracy: 0.8700 - 2ms/epoch - 382us/step
# Epoch 124/150
# 4/4 - 0s - loss: 0.4408 - accuracy: 0.8900 - 2ms/epoch - 502us/step
# Epoch 125/150
# 4/4 - 0s - loss: 0.4383 - accuracy: 0.8900 - 2ms/epoch - 585us/step
# Epoch 126/150
# 4/4 - 0s - loss: 0.4354 - accuracy: 0.8900 - 2ms/epoch - 417us/step
# Epoch 127/150
# 4/4 - 0s - loss: 0.4329 - accuracy: 0.8700 - 2ms/epoch - 381us/step
# Epoch 128/150
# 4/4 - 0s - loss: 0.4307 - accuracy: 0.8500 - 2ms/epoch - 417us/step
# Epoch 129/150
# 4/4 - 0s - loss: 0.4296 - accuracy: 0.8100 - 2ms/epoch - 519us/step
# Epoch 130/150
# 4/4 - 0s - loss: 0.4287 - accuracy: 0.7800 - 2ms/epoch - 560us/step
# Epoch 131/150
# 4/4 - 0s - loss: 0.4269 - accuracy: 0.7800 - 2ms/epoch - 411us/step
# Epoch 132/150
# 4/4 - 0s - loss: 0.4242 - accuracy: 0.7800 - 1ms/epoch - 374us/step
# Epoch 133/150
# 4/4 - 0s - loss: 0.4213 - accuracy: 0.7800 - 2ms/epoch - 467us/step
# Epoch 134/150
# 4/4 - 0s - loss: 0.4182 - accuracy: 0.8200 - 2ms/epoch - 409us/step
# Epoch 135/150
# 4/4 - 0s - loss: 0.4149 - accuracy: 0.8500 - 1ms/epoch - 366us/step
# Epoch 136/150
# 4/4 - 0s - loss: 0.4122 - accuracy: 0.8600 - 2ms/epoch - 406us/step
# Epoch 137/150
# 4/4 - 0s - loss: 0.4097 - accuracy: 0.8800 - 2ms/epoch - 531us/step
# Epoch 138/150
# 4/4 - 0s - loss: 0.4073 - accuracy: 0.9000 - 3ms/epoch - 706us/step
# Epoch 139/150
# 4/4 - 0s - loss: 0.4049 - accuracy: 0.9000 - 2ms/epoch - 459us/step
# Epoch 140/150
# 4/4 - 0s - loss: 0.4025 - accuracy: 0.9000 - 2ms/epoch - 383us/step
# Epoch 141/150
# 4/4 - 0s - loss: 0.4000 - accuracy: 0.9000 - 2ms/epoch - 407us/step
# Epoch 142/150
# 4/4 - 0s - loss: 0.3978 - accuracy: 0.9000 - 2ms/epoch - 510us/step
# Epoch 143/150
# 4/4 - 0s - loss: 0.3956 - accuracy: 0.9000 - 2ms/epoch - 420us/step
# Epoch 144/150
# 4/4 - 0s - loss: 0.3921 - accuracy: 0.9200 - 2ms/epoch - 567us/step
# Epoch 145/150
# 4/4 - 0s - loss: 0.3896 - accuracy: 0.9200 - 2ms/epoch - 507us/step
# Epoch 146/150
# 4/4 - 0s - loss: 0.3883 - accuracy: 0.9200 - 2ms/epoch - 495us/step
# Epoch 147/150
# 4/4 - 0s - loss: 0.3860 - accuracy: 0.9300 - 2ms/epoch - 407us/step
# Epoch 148/150
# 4/4 - 0s - loss: 0.3842 - accuracy: 0.9300 - 2ms/epoch - 426us/step
# Epoch 149/150
# 4/4 - 0s - loss: 0.3805 - accuracy: 0.9200 - 2ms/epoch - 382us/step
# Epoch 150/150
# 4/4 - 0s - loss: 0.3778 - accuracy: 0.9200 - 3ms/epoch - 656us/step
